# %% [markdown]
# ***Violinplot of "Likely to recommend Instruction Partners"***
#
# A violinplot is similar to a box and whisker plot or density map. It shows the distribution of quantitative data *(Likely to recommend IP, 1-10)* across categories *(Submitter roles)* such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a density estimation of the distribution.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %% [markdown]
# ***Reading data***

# %%
df=pd.read_csv('Partnership Data Lead _ Systems and Data Analyst - Content Exercise Data.csv')

# %% [markdown]
# ***Establishing themes, size and color settings***

# %%
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(20,8.27)})

# %% [markdown]
# ***The violinplot, with each category scaled to have the same area with medians identified (white dots)***

# %%
ax = sns.violinplot(x="Submitter Role", y="Likely to recommend Instruction Partners", data=df, cut=0, inner="box")
